# %%
import os
import cv2
import time
path = "C:\\Users\\heaven\\Desktop\\project\\000\\000"
c = 1
file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\000\\001"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\000\\002"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\000\\003"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\000\\004"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\000\\005"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\100\\100"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\100\\101"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\100\\102"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\200\\200"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\200\\201"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\200\\202"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\200\\203"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\200\\204"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\200\\205"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\300\\300"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\300\\301"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\300\\302"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\300\\303"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\400\\400"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
time.sleep(3)

path = "C:\\Users\\heaven\\Desktop\\project\\400\\403"

file_list = os.listdir(path)
file_list1 = [path+'\\'+str(i) for i in file_list]
for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    resize = cv2.resize(img, (32, 32), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\" \
                + str(c) + '.jpg',resize)
    c = c+1
print(c)
# Out:
# 785
# 940
# 1192
# 1405
# 1633
# 1804
# 2431
# 2881
# 3231
# 3529
# 3782
# 4146
# 4388
# 4896
# 5383
# 5949
# 6252
# 6626
# 6765
# 7376
# 7749

# %%
import os
import cv2

path = "C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2\\"
    
file_list = os.listdir(path)
file_name = sorted([int(i[:-4]) for i in file_list])
file_list1 = [path+'\\'+str(i)+'.jpg' for i in file_name]

for j,i in enumerate(file_list1):
    img = cv2.imread(i)
    img = cv2.flip(img, 1)
    cv2.imwrite("C:\\Users\\heaven\\python_project\\test_data\\test_image_32_2\\" + str(j+1) + '.jpg',img)

# %%
f = open('C:\\Users\\heaven\\python_project\\test_data\\label2.csv','w')


text_save = []
for i in range(0,784):
    text_save.append('0' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,155):
    text_save.append('1' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,252):
    text_save.append('2' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,213):
    text_save.append('3' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,228):
    text_save.append('4' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,171):
    text_save.append('5' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,627):
    text_save.append('6' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,450):
    text_save.append('7' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,350):
    text_save.append('8' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,298):
    text_save.append('9' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,253):
    text_save.append('10' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,364):
    text_save.append('11' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,242):
    text_save.append('12' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,508):
    text_save.append('13' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,487):
    text_save.append('14' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,566):
    text_save.append('15' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,303):
    text_save.append('16' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,374):
    text_save.append('17' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,139):
    text_save.append('18' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,611):
    text_save.append('19' + '\n')
f.writelines(text_save)

text_save = []
for i in range(0,373):
    text_save.append('20' + '\n')
f.writelines(text_save)

f.close()

# %%
import loader3

train_image = "C:\\Users\\heaven\\python_project\\test_data\\total_image_32_2"
train_label = "C:\\Users\\heaven\\python_project\\test_data\\label2.csv"

trainX = loader3.image_load(train_image)
trainY = loader3.label_load(train_label)

print(trainX.shape)
print(trainY.shape)
# Out:
# (7748, 32, 32, 3)
# (7748, 21)

# %%
print(trainY[1])
# Out:
# [1. 0. 0. 0.]
